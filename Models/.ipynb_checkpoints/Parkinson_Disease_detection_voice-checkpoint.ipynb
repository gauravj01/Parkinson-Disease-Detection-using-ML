# %% [markdown]
# # 1. Importing Required Libraries

# %%
import numpy as np 
from sklearn import metrics
import os
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay ,classification_report, roc_auc_score

# %% [markdown]
# ## 2. Dataset Walkthrough
# 1.   Loading the Dataset
# 2.   Viewing the dataset
#
# 1.   Shape of Dataset
# 2.   Basic description
#
# 1.   Checking for NULL values

# %%
df = pd.read_csv("parkinsons.csv")

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %% [markdown]
# ## 3. About Data

# %% [markdown]
# *   name - ASCII subject name and recording number
#
# *   MDVP:Fo(Hz) - Average vocal fundamental frequency
#
# *   MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
#
# *   MDVP:Flo(Hz) - Minimum vocal fundamental frequency
#
# *   MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several measures of variation in fundamental frequency
#
# *   MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
#
# *   NHR,HNR - Two measures of ratio of noise to tonal components in the voice
#
# *   status - Health status of the subject (one) - Parkinson's, (zero) - healthy
#
# *   RPDE,D2 - Two nonlinear dynamical complexity measures
#
# *   DFA - Signal fractal scaling exponent
#
# *   spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %%
df.hist(figsize=(25,16))
plt.show()

# %%
sns.pairplot(df.iloc[: ,0:6])
plt.show()

# %%
f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(df.corr(), annot = True, fmt= '.3f')
plt.show()
# Out:
# C:\Users\gaurav\AppData\Local\Temp\ipykernel_11740\4018377997.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, fmt= '.3f')

# %%
df_ = df[df['status'] == 1]

# %%
df_ = df_.drop(['status'], axis=1)

# %%
df_['MDVP:Shimmer'].describe()
# Out:
# count    147.000000
# mean       0.033658
# std        0.019970
# min        0.010220
# 25%        0.018295
# 50%        0.028380
# 75%        0.042525
# max        0.119080
# Name: MDVP:Shimmer, dtype: float64

# %%
df_['MDVP:Jitter(%)'].describe()
# Out:
# count    147.000000
# mean       0.006989
# std        0.005240
# min        0.001680
# 25%        0.004005
# 50%        0.005440
# 75%        0.007670
# max        0.033160
# Name: MDVP:Jitter(%), dtype: float64

# %%
features=df.loc[:,df.columns!='status'].values[:,1:]
labels=df.loc[:,'status'].values

# %%
print(labels[labels==1].shape[0],labels[labels==0].shape[0])
# Out:
# 147 48

# %%
scaler = MinMaxScaler((-1,1))
x=scaler.fit_transform(features)
y=labels

# %% [markdown]
# ## 5. Train/Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=7)

# %% [markdown]
# ## 6. Buillding different models
#
# 1. Create model
# 2. fit the model
# 3. Prediction
# 4. Calculate accuracy
# 5. Classification report
# 6. Confusion Matrix

# %% [markdown]
# #### 6.1) Using Decision tree

# %%
decision_tree = DecisionTreeClassifier()

decision_tree.fit(x_train, y_train)

y_pred_dt = decision_tree.predict(x_test)

acc_dt = accuracy_score(y_test, y_pred_dt)*100

print("Accuracy using Decision tree: ", round(acc_dt, 2))
# Out:
# Accuracy using Decision tree:  87.18

# %% [markdown]
# #### 6.3) Using Random Forest

# %%
rf = RandomForestClassifier()

rf.fit(x_train, y_train)

y_pred_rf = rf.predict(x_test)

acc_rf = accuracy_score(y_test, y_pred_rf)*100

print("Accuracy using Random forest", round(acc_rf,2))
# Out:
# Accuracy using Random forest 92.31

# %% [markdown]
# #### 6.3) Using XGBoost

# %%
model=XGBClassifier(learning_rate=0.1,max_depth=20,verbosity=2,
               random_state=42,scale_pos_weight=1.5,eval_metric='mlogloss',use_label_encoder=False)

model.fit(x_train,y_train)

XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
              eval_metric='mlogloss', gamma=0, gpu_id=-1, importance_type=None,
              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
              max_depth=20, min_child_weight=1, missing=np.nan,
              monotone_constraints='()', n_estimators=100, n_jobs=4,
              num_parallel_tree=1, predictor='auto', random_state=42,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1.5, subsample=1,
              tree_method='exact', use_label_encoder=False,
              validate_parameters=1, verbosity=2)

y_pred_xgb = model.predict(x_test)
# Out:
# [17:53:05] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [17:53:05] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [17:53:05] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [17:53:05] INFO: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-08de971ced8a8cdc6-1/xgboost/xgboost-ci-windows/src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# ...

# %%
acc_xgb = accuracy_score(y_test,y_pred_xgb)*100
print("Accuracy using XGBoost: ",round(acc_xgb, 2))
# Out:
# Accuracy using XGBoost:  92.31

# %% [markdown]
# Classification Report:

# %%
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71         7
#            1       0.97      0.88      0.92        32
#
#     accuracy                           0.87        39
#    macro avg       0.78      0.87      0.81        39
# weighted avg       0.90      0.87      0.88        39

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73         7
#            1       0.91      1.00      0.96        32
#
#     accuracy                           0.92        39
#    macro avg       0.96      0.79      0.84        39
# weighted avg       0.93      0.92      0.91        39

# %%
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.92        39
#    macro avg       0.89      0.84      0.86        39
# weighted avg       0.92      0.92      0.92        39

# %%
cm_dt = confusion_matrix(y_test,y_pred_dt)
cm_rf = confusion_matrix(y_test,y_pred_rf)
cm_xgb = confusion_matrix(y_test,y_pred_xgb)

disp1 = ConfusionMatrixDisplay(cm_dt)
disp2 = ConfusionMatrixDisplay(cm_rf)
disp3 = ConfusionMatrixDisplay(cm_xgb)

disp1.plot()
disp2.plot()
disp3.plot()

plt.show()

# %% [markdown]
# ## 7. Prediction using custom values

# %%
newinput=[[274.688,240.005,174.287,0.01360,0.01008,0.00624,0.00564,0.01873, 1.02308,0.256,0.51268,0.01365,0.81667,0.63804,0.10715,6.883,0.607567,0.158453,3.679772,0.131728,3.679772, 0.131728]]

# %%
output_dt = decision_tree.predict(newinput)
output_rf = rf.predict(newinput)
output_xgb = model.predict(newinput)

# %%
def check_(op):
    if op == 1:
        print("The person have Parkinsons")
    else:
        print("No parkinsons detected")

# %%
check_(output_dt)
check_(output_rf)
check_(output_xgb)
# Out:
# The person have Parkinsons
# The person have Parkinsons
# The person have Parkinsons

# %% [markdown]
# **learning rate**=In machine learning and statistics, the learning rate is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.
#
# **max-depth**=Maximum depth refers to the the length of the longest path from a root to a leaf.
#
# **verbosity**=Verbosity in keyword arguments usually means showing more 'wordy' information for the task. In this case, for machine learning, by setting verbose to a higher number ( 2 vs 1 ), you may see more information about the tree building process.
#
# **random_state**=The random state hyperparameter is used to control any such randomness involved in machine learning models to get consistent results.
#
# **scale_pos weight** =The scale_pos_weight value is used to scale the gradient for the positive class. This has the effect of scaling errors made by the model during training on the positive class and encourages the model to over-correct them.
#
# **eval_metric** = to measure your error on these evaluation sets.
#
# **use_label_encoder**=Label Encoding refers to converting the labels into a numeric form so as to convert them into the machine-readable form
